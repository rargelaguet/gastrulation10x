# %% [markdown]
# # Blood Exploration

# %%
exec(open('/Users/ricard/gastrulation10x/settings.py').read())
# Out:
# /Users/ricard/anaconda3/envs/base_new/lib/python3.6/site-packages/anndata/compat/__init__.py:161: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   FutureWarning,
# /Users/ricard/anaconda3/envs/base_new/lib/python3.6/site-packages/anndata/compat/__init__.py:161: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   FutureWarning,

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, frameon=False, figsize=(5, 5), facecolor='white')
# sc.logging.print_versions()

# %%
colPalette_celltypes = [opts["celltype_colors"][i.replace(" ","_")] for i in sorted(np.unique(adata.obs['celltype']))]
adata.uns['celltype_colors'] = colPalette_celltypes

# %% [markdown]
# ## Subset

# %%
blood_lineages = ["Mesenchyme","Haematoendothelial_progenitors","Endothelium","Blood_progenitors_1","Blood_progenitors_2","Erythroid1","Erythroid2","Erythroid3"]

# %%
adata_subset = adata[adata.obs["celltype"].isin(blood_lineages)]
# Out:
# /Users/ricard/anaconda3/envs/base_new/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
adata_subset.obs["celltype"].value_counts()
# Out:
# Erythroid1                        2929
# Haematoendothelial_progenitors    2733
# Erythroid3                        2697
# Blood_progenitors_2               2587
# Erythroid2                        1106
# Endothelium                       1084
# Blood_progenitors_1                745
# Name: celltype, dtype: int64

# %%
sc.pl.scatter(adata_subset, color='celltype', basis="umap", size=5, legend_loc='on data', legend_fontsize=7)

# %% [markdown]
# ## Feature selection

# %%
sc.pp.highly_variable_genes(adata_subset, n_top_genes=500)
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(adata_subset)

# %%
adata_subset.var["highly_variable"].sum()
# Out:
# 500

# %% [markdown]
# ## Dimensionality reduction

# %%
sc.tl.pca(adata_subset, n_comps=25)
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=25
# /Users/ricard/anaconda3/envs/base_new/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
#     finished (0:00:00)

# %%
sc.tl.umap(adata_subset, min_dist=0.5, spread=1.0)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:14)

# %%
sc.pl.scatter(adata_subset, color='celltype', basis="umap", size=5, legend_loc='on data', legend_fontsize=7)

# %%
adata_subset.obsm.keys()
# Out:
# KeysView(AxisArrays with keys: X_pca, X_umap, X_tsne, X_diffmap)

# %%
sc.pp.neighbors(adata_subset, n_neighbors=15, use_rep='X_pca')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:18)

# %%
sc.tl.paga(adata_subset, groups='celltype')
# Out:
# running PAGA
#     finished: added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns) (0:00:00)

# %% [markdown]
# ## Force-directed layout

# %%
sc.tl.draw_graph(adata_subset, layout='fa', init_pos=None)
# Out:
# drawing single-cell graph using layout 'fa'
#     finished: added
#     'X_draw_graph_fa', graph_drawing coordinates (adata.obsm) (0:02:26)

# %%
sc.pl.draw_graph(adata_subset, color='celltype', legend_loc='on data')

# %% [markdown]
# recomputing the graph using PAGA initialisation

# %%
sc.tl.draw_graph(adata_subset, layout='fa', init_pos="paga")
sc.pl.draw_graph(adata_subset, color='celltype', legend_loc='on data')
# Out:
# drawing single-cell graph using layout 'fa'

# %% [markdown]
# ## Plotting graph abstraction

# %%
sc.pl.paga_compare(adata_subset, basis='umap',legend_loc='on data',
                   fontsize=3, threshold=0.23, color='celltype', edge_width_scale=0.1)
# Out:
# --> added 'pos', the PAGA positions (adata.uns['paga'])

# %%
sc.pl.paga(adata_subset, threshold=0.3, fontsize=3, edge_width_scale=0.15, node_size_power=0.5, color='celltype')
# Out:
# --> added 'pos', the PAGA positions (adata.uns['paga'])
